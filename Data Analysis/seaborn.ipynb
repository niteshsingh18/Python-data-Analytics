# %%
import seaborn as sns
import numpy as numpy

# %%
x = np.random.normal()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 x = np.random
#
# NameError: name 'np' is not defined

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set_theme(style='darkgrid')

# %%
sns.relplot(data=tips, x='total_bill', y = 'tip', aspect = 1.5, height=4)

# %%
sns.relplot(data=tips, x="total_bill", y="tip", hue='sex')

# %%
sns.relplot(data=tips, x="total_bill", y="tip", hue='sex',
            palette=['y', 'g'], edgecolor='black', aspect=2)

# %%
sns.relplot(data=tips, x="total_bill", y="tip", hue='smoker', style='smoker',
            palette=['y', 'g'], edgecolor='black', aspect=2)

# %%
sns.relplot(data=tips, x="total_bill", y="tip", hue='time',
            palette=['y', 'g'], edgecolor='black', aspect=2)

# %%
sns.relplot(data=tips, x="total_bill", y="tip", hue='day',
            palette=['y', 'g', 'b', 'r'], edgecolor='black', aspect=2)

# %%
sns.relplot(
    data=tips,
    x="total_bill", y="tip", hue="smoker", style="smoker"
)

# %%
sns.relplot(
    data=tips, x="total_bill", y="tip", hue="size",
)

# %%
sns.relplot(
    data=tips, x="total_bill", y="tip", hue="size",palette='hot'
)

# %%
sns.relplot(
    data=tips, x='total_bill', y='tip',
    size='total_bill', aspect=3,
    sizes=(20,200), alpha=.5, edgecolor='blue'
)

# %%
dowjones = sns.load_dataset("dowjones")
dowjones
# Out:
#           Date   Price
# 0   1914-12-01   55.00
# 1   1915-01-01   56.55
# 2   1915-02-01   56.00
# 3   1915-03-01   58.30
# 4   1915-04-01   66.45
# ..         ...     ...
# 644 1968-08-01  883.72
# 645 1968-09-01  922.80
# 646 1968-10-01  955.47
# 647 1968-11-01  964.12
# 648 1968-12-01  965.39
#
# [649 rows x 2 columns]

# %%
dowjones = sns.load_dataset("dowjones")
sns.relplot(data=dowjones, x="Date", y="Price", kind="line", aspect=2)

# %%
fmri = sns.load_dataset("fmri")
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(data=fmri, x="timepoint", y="signal", kind="line", aspect=2)

# %%
sns.relplot(data=fmri, x="timepoint", y="signal", kind="line", aspect=2, hue='event')

# %%
sns.relplot(data=fmri, x="timepoint", y="signal", kind="line", aspect=2, col='event')

# %%
sns.relplot(data=fmri, x="timepoint", y="signal", kind="line", aspect=1, col='subject')

# %%
sns.relplot(data=fmri, x="timepoint", y="signal", kind="line", aspect=1, row='subject')
