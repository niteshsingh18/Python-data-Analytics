# %%
import numpy as np 
import pandas as pd

# %%
dict1 =  {"Name":['Rohan', 'Rohit', 'Raunak', 'Raman'],
          "Marks":[45,65,67,78],
          "City":['Delhi', 'Mumbai', 'Kolkata', 'Chennai']
          }

# %%
nf = pd.DataFrame(dict1)
nf
# Out:
#      Name  Marks     City
# 0   Rohan     45    Delhi
# 1   Rohit     65   Mumbai
# 2  Raunak     67  Kolkata
# 3   Raman     78  Chennai

# %%
nf.to_csv('pan.csv')

# %%
import pandas as pd
import numpy as np 
import matplotlib as plt
import seaborn as sns

# %%
path = 'data/cardioActivities.csv'
df = pd.read_csv(path)
df
# Out:
#                     Date                           Activity Id     Type  \
# 0    2018-11-11 14:05:12  c9627fed-14ac-47a2-bed3-2a2630c63c15  Running
# 1    2018-11-09 15:02:35  be65818d-a801-4847-a43b-2acdf4dc70e7  Running
# 2    2018-11-04 16:05:00  c09b2f92-f855-497c-b624-c196b3ef036c  Running
# 3    2018-11-01 14:03:58  bc9b612d-3499-43ff-b82a-9b17b71b8a36  Running
# 4    2018-10-27 17:01:36  972567b2-1b0e-437c-9e82-fef8078d6438  Running
# ..                   ...                                   ...      ...
# 503  2012-08-28 07:06:57  f5218490-a372-44c8-bb20-de3b91984cbe  Walking
# 504  2012-08-24 12:59:42  018f66a7-da5e-4985-a8fe-725a33317c87  Walking
# 505  2012-08-24 10:12:16  7acec95a-d63d-435d-837c-7befb352f500  Walking
# 506  2012-08-24 08:13:12  f790bdb2-b921-4018-bd39-d59d870c5847  Running
# 507  2012-08-22 18:53:54  706d4d6b-767d-40aa-81c9-e5e85a102051  Running
#
#     Route Name  Distance (km) Duration Average Pace  Average Speed (km/h)  \
# 0          NaN          10.44    58:40         5:37                 10.68
# 1          NaN          12.84  1:14:12         5:47                 10.39
# 2          NaN          13.01  1:15:16         5:47                 10.37
# 3          NaN          12.98  1:14:25         5:44                 10.47
# 4          NaN          13.02  1:12:50         5:36                 10.73
# ..         ...            ...      ...          ...                   ...
# 503        NaN           1.57    13:39         8:41                  6.91
# 504        NaN           1.48    17:56        12:09                  4.94
# 505        NaN           1.49    13:43         9:14                  6.49
# 506        NaN           3.15    16:00         5:05                 11.82
# 507        NaN           5.69    31:08         5:29                 10.95
#
#      Calories Burned  Climb (m)  Average Heart Rate (bpm)  Friend's Tagged  \
# 0              774.0        130                     159.0              NaN
# 1              954.0        168                     159.0              NaN
# 2              967.0        171                     155.0              NaN
# 3              960.0        169                     158.0              NaN
# 4              967.0        170                     154.0              NaN
# ..               ...        ...                       ...              ...
# 503         926743.0          7                       NaN              NaN
# 504         942192.0         12                       NaN              NaN
# 505         924486.0          9                       NaN              NaN
# 506        2288868.0         17                       NaN              NaN
# 507        4072685.0         32                       NaN              NaN
#
#     Notes               GPX File
# 0     NaN  2018-11-11-140512.gpx
# 1     NaN  2018-11-09-150235.gpx
# 2     NaN  2018-11-04-160500.gpx
# 3     NaN  2018-11-01-140358.gpx
# 4     NaN  2018-10-27-170136.gpx
# ..    ...                    ...
# 503   NaN  2012-08-28-070657.gpx
# 504   NaN  2012-08-24-125942.gpx
# 505   NaN  2012-08-24-101216.gpx
# 506   NaN  2012-08-24-081312.gpx
# 507   NaN  2012-08-22-185354.gpx
#
# [508 rows x 14 columns]

# %%
df
# Out:
#                     Date                           Activity Id     Type  \
# 0    2018-11-11 14:05:12  c9627fed-14ac-47a2-bed3-2a2630c63c15  Running
# 1    2018-11-09 15:02:35  be65818d-a801-4847-a43b-2acdf4dc70e7  Running
# 2    2018-11-04 16:05:00  c09b2f92-f855-497c-b624-c196b3ef036c  Running
# 3    2018-11-01 14:03:58  bc9b612d-3499-43ff-b82a-9b17b71b8a36  Running
# 4    2018-10-27 17:01:36  972567b2-1b0e-437c-9e82-fef8078d6438  Running
# ..                   ...                                   ...      ...
# 503  2012-08-28 07:06:57  f5218490-a372-44c8-bb20-de3b91984cbe  Walking
# 504  2012-08-24 12:59:42  018f66a7-da5e-4985-a8fe-725a33317c87  Walking
# 505  2012-08-24 10:12:16  7acec95a-d63d-435d-837c-7befb352f500  Walking
# 506  2012-08-24 08:13:12  f790bdb2-b921-4018-bd39-d59d870c5847  Running
# 507  2012-08-22 18:53:54  706d4d6b-767d-40aa-81c9-e5e85a102051  Running
#
#     Route Name  Distance (km) Duration Average Pace  Average Speed (km/h)  \
# 0          NaN          10.44    58:40         5:37                 10.68
# 1          NaN          12.84  1:14:12         5:47                 10.39
# 2          NaN          13.01  1:15:16         5:47                 10.37
# 3          NaN          12.98  1:14:25         5:44                 10.47
# 4          NaN          13.02  1:12:50         5:36                 10.73
# ..         ...            ...      ...          ...                   ...
# 503        NaN           1.57    13:39         8:41                  6.91
# 504        NaN           1.48    17:56        12:09                  4.94
# 505        NaN           1.49    13:43         9:14                  6.49
# 506        NaN           3.15    16:00         5:05                 11.82
# 507        NaN           5.69    31:08         5:29                 10.95
#
#      Calories Burned  Climb (m)  Average Heart Rate (bpm)  Friend's Tagged  \
# 0              774.0        130                     159.0              NaN
# 1              954.0        168                     159.0              NaN
# 2              967.0        171                     155.0              NaN
# 3              960.0        169                     158.0              NaN
# 4              967.0        170                     154.0              NaN
# ..               ...        ...                       ...              ...
# 503         926743.0          7                       NaN              NaN
# 504         942192.0         12                       NaN              NaN
# 505         924486.0          9                       NaN              NaN
# 506        2288868.0         17                       NaN              NaN
# 507        4072685.0         32                       NaN              NaN
#
#     Notes               GPX File
# 0     NaN  2018-11-11-140512.gpx
# 1     NaN  2018-11-09-150235.gpx
# 2     NaN  2018-11-04-160500.gpx
# 3     NaN  2018-11-01-140358.gpx
# 4     NaN  2018-10-27-170136.gpx
# ..    ...                    ...
# 503   NaN  2012-08-28-070657.gpx
# 504   NaN  2012-08-24-125942.gpx
# 505   NaN  2012-08-24-101216.gpx
# 506   NaN  2012-08-24-081312.gpx
# 507   NaN  2012-08-22-185354.gpx
#
# [508 rows x 14 columns]

# %%
# optional settings for viewing all columns
pd.set_option('display.max_columns', None)

# %%
df # dont display df using print() function
# Out:
#                     Date                           Activity Id     Type  \
# 0    2018-11-11 14:05:12  c9627fed-14ac-47a2-bed3-2a2630c63c15  Running
# 1    2018-11-09 15:02:35  be65818d-a801-4847-a43b-2acdf4dc70e7  Running
# 2    2018-11-04 16:05:00  c09b2f92-f855-497c-b624-c196b3ef036c  Running
# 3    2018-11-01 14:03:58  bc9b612d-3499-43ff-b82a-9b17b71b8a36  Running
# 4    2018-10-27 17:01:36  972567b2-1b0e-437c-9e82-fef8078d6438  Running
# ..                   ...                                   ...      ...
# 503  2012-08-28 07:06:57  f5218490-a372-44c8-bb20-de3b91984cbe  Walking
# 504  2012-08-24 12:59:42  018f66a7-da5e-4985-a8fe-725a33317c87  Walking
# 505  2012-08-24 10:12:16  7acec95a-d63d-435d-837c-7befb352f500  Walking
# 506  2012-08-24 08:13:12  f790bdb2-b921-4018-bd39-d59d870c5847  Running
# 507  2012-08-22 18:53:54  706d4d6b-767d-40aa-81c9-e5e85a102051  Running
#
#     Route Name  Distance (km) Duration Average Pace  Average Speed (km/h)  \
# 0          NaN          10.44    58:40         5:37                 10.68
# 1          NaN          12.84  1:14:12         5:47                 10.39
# 2          NaN          13.01  1:15:16         5:47                 10.37
# 3          NaN          12.98  1:14:25         5:44                 10.47
# 4          NaN          13.02  1:12:50         5:36                 10.73
# ..         ...            ...      ...          ...                   ...
# 503        NaN           1.57    13:39         8:41                  6.91
# 504        NaN           1.48    17:56        12:09                  4.94
# 505        NaN           1.49    13:43         9:14                  6.49
# 506        NaN           3.15    16:00         5:05                 11.82
# 507        NaN           5.69    31:08         5:29                 10.95
#
#      Calories Burned  Climb (m)  Average Heart Rate (bpm)  Friend's Tagged  \
# 0              774.0        130                     159.0              NaN
# 1              954.0        168                     159.0              NaN
# 2              967.0        171                     155.0              NaN
# 3              960.0        169                     158.0              NaN
# 4              967.0        170                     154.0              NaN
# ..               ...        ...                       ...              ...
# 503         926743.0          7                       NaN              NaN
# 504         942192.0         12                       NaN              NaN
# 505         924486.0          9                       NaN              NaN
# 506        2288868.0         17                       NaN              NaN
# 507        4072685.0         32                       NaN              NaN
#
#     Notes               GPX File
# 0     NaN  2018-11-11-140512.gpx
# 1     NaN  2018-11-09-150235.gpx
# 2     NaN  2018-11-04-160500.gpx
# 3     NaN  2018-11-01-140358.gpx
# 4     NaN  2018-10-27-170136.gpx
# ..    ...                    ...
# 503   NaN  2012-08-28-070657.gpx
# 504   NaN  2012-08-24-125942.gpx
# 505   NaN  2012-08-24-101216.gpx
# 506   NaN  2012-08-24-081312.gpx
# 507   NaN  2012-08-22-185354.gpx
#
# [508 rows x 14 columns]

# %% [markdown]
# # basic pandas operations
# - head(n) : returns the first n rows of a DataFrame
# - tail(n) : returns the last n rows of a DataFrame
# - info() : Index, Column Datatype and Memory information
# - describe() : Summary statistics for numerical columns
# - describe(include=['object']) : Summary statistics for object columns

# %%
df.head() # display first 5 rows
# Out:
#                   Date                           Activity Id     Type  \
# 0  2018-11-11 14:05:12  c9627fed-14ac-47a2-bed3-2a2630c63c15  Running
# 1  2018-11-09 15:02:35  be65818d-a801-4847-a43b-2acdf4dc70e7  Running
# 2  2018-11-04 16:05:00  c09b2f92-f855-497c-b624-c196b3ef036c  Running
# 3  2018-11-01 14:03:58  bc9b612d-3499-43ff-b82a-9b17b71b8a36  Running
# 4  2018-10-27 17:01:36  972567b2-1b0e-437c-9e82-fef8078d6438  Running
#
#   Route Name  Distance (km) Duration Average Pace  Average Speed (km/h)  \
# 0        NaN          10.44    58:40         5:37                 10.68
# 1        NaN          12.84  1:14:12         5:47                 10.39
# 2        NaN          13.01  1:15:16         5:47                 10.37
# 3        NaN          12.98  1:14:25         5:44                 10.47
# 4        NaN          13.02  1:12:50         5:36                 10.73
#
#    Calories Burned  Climb (m)  Average Heart Rate (bpm)  Friend's Tagged  \
# 0            774.0        130                     159.0              NaN
# 1            954.0        168                     159.0              NaN
# 2            967.0        171                     155.0              NaN
# 3            960.0        169                     158.0              NaN
# 4            967.0        170                     154.0              NaN
#
#   Notes               GPX File
# 0   NaN  2018-11-11-140512.gpx
# 1   NaN  2018-11-09-150235.gpx
# 2   NaN  2018-11-04-160500.gpx
# 3   NaN  2018-11-01-140358.gpx
# 4   NaN  2018-10-27-170136.gpx

# %%
df.head(10)
# Out:
#                   Date                           Activity Id     Type  \
# 0  2018-11-11 14:05:12  c9627fed-14ac-47a2-bed3-2a2630c63c15  Running
# 1  2018-11-09 15:02:35  be65818d-a801-4847-a43b-2acdf4dc70e7  Running
# 2  2018-11-04 16:05:00  c09b2f92-f855-497c-b624-c196b3ef036c  Running
# 3  2018-11-01 14:03:58  bc9b612d-3499-43ff-b82a-9b17b71b8a36  Running
# 4  2018-10-27 17:01:36  972567b2-1b0e-437c-9e82-fef8078d6438  Running
# 5  2018-10-19 17:52:32  fe2cb3fc-6330-40fa-8a92-0f86f4e72282  Running
# 6  2018-10-14 17:28:56  96acedc9-d3d5-4aac-8df4-f549a6418c1d  Running
# 7  2018-10-12 17:41:58  3c91092b-e6f3-4565-b540-6b6537358006  Running
# 8  2018-10-06 16:45:02  4c163abe-3a57-42fd-b50b-7f365960cbd4  Cycling
# 9  2018-09-30 16:52:34  70c7f2ba-f4cb-4403-a9e4-bf2c9b93bb05  Running
#
#   Route Name  Distance (km) Duration Average Pace  Average Speed (km/h)  \
# 0        NaN          10.44    58:40         5:37                 10.68
# 1        NaN          12.84  1:14:12         5:47                 10.39
# 2        NaN          13.01  1:15:16         5:47                 10.37
# 3        NaN          12.98  1:14:25         5:44                 10.47
# 4        NaN          13.02  1:12:50         5:36                 10.73
# 5        NaN          10.29    59:18         5:46                 10.41
# 6        NaN          12.93  1:10:16         5:26                 11.04
# 7        NaN          12.31  1:09:26         5:38                 10.64
# 8        NaN          19.63  1:26:26         4:24                 13.63
# 9        NaN          12.97  1:13:56         5:42                 10.52
#
#    Calories Burned  Climb (m)  Average Heart Rate (bpm)  Friend's Tagged  \
# 0            774.0        130                     159.0              NaN
# 1            954.0        168                     159.0              NaN
# 2            967.0        171                     155.0              NaN
# 3            960.0        169                     158.0              NaN
# 4            967.0        170                     154.0              NaN
# 5            764.0        133                     155.0              NaN
# 6            953.0        159                     158.0              NaN
# 7            903.0        134                     157.0              NaN
# 8            577.0        210                      79.0              NaN
# 9            964.0        171                     156.0              NaN
#
#   Notes               GPX File
# 0   NaN  2018-11-11-140512.gpx
# 1   NaN  2018-11-09-150235.gpx
# 2   NaN  2018-11-04-160500.gpx
# 3   NaN  2018-11-01-140358.gpx
# 4   NaN  2018-10-27-170136.gpx
# 5   NaN  2018-10-19-175232.gpx
# 6   NaN  2018-10-14-172856.gpx
# 7   NaN  2018-10-12-174158.gpx
# 8   NaN  2018-10-06-164502.gpx
# 9   NaN  2018-09-30-165234.gpx

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 508 entries, 0 to 507
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      508 non-null    object
#  1   Activity Id               508 non-null    object
#  2   Type                      508 non-null    object
#  3   Route Name                1 non-null      object
#  4   Distance (km)             508 non-null    float64
#  5   Duration                  508 non-null    object
#  6   Average Pace              508 non-null    object
#  7   Average Speed (km/h)      508 non-null    float64
#  8   Calories Burned           508 non-null    float64
#  9   Climb (m)                 508 non-null    int64
#  10  Average Heart Rate (bpm)  294 non-null    float64
#  11  Friend's Tagged           0 non-null      float64
#  12  Notes                     231 non-null    object
#  13  GPX File                  504 non-null    object
# dtypes: float64(5), int64(1), object(8)
# memory usage: 55.7+ KB

# %%
df.describe()
# Out:
#        Distance (km)  Average Speed (km/h)  Calories Burned  Climb (m)  \
# count     508.000000            508.000000     5.080000e+02  508.00000
# mean       11.757835             11.341654     1.878197e+04  128.00000
# std         6.209219              2.510516     2.186930e+05  108.52604
# min         0.760000              1.040000     4.000000e+01    0.00000
# 25%         7.015000             10.470000     4.917500e+02   53.00000
# 50%        11.460000             11.030000     7.280884e+02   92.00000
# 75%        13.642500             11.642500     9.212500e+02  172.25000
# max        49.180000             24.330000     4.072685e+06  982.00000
#
#        Average Heart Rate (bpm)  Friend's Tagged
# count                294.000000              0.0
# mean                 143.530612              NaN
# std                   10.583848              NaN
# min                   77.000000              NaN
# 25%                  140.000000              NaN
# 50%                  144.000000              NaN
# 75%                  149.000000              NaN
# max                  172.000000              NaN

# %% [markdown]
# object datatype in pandas is equivalent to string datatype in python

# %%
df.describe(include=['object'])
# Out:
#                        Date                           Activity Id     Type  \
# count                   508                                   508      508
# unique                  508                                   508        4
# top     2018-11-11 14:05:12  c9627fed-14ac-47a2-bed3-2a2630c63c15  Running
# freq                      1                                     1      459
#
#                Route Name Duration Average Pace                  Notes  \
# count                   1      508          508                    231
# unique                  1      458          146                      7
# top     Two roads - Irpin    32:00         5:24  TomTom MySports Watch
# freq                    1        6           16                    225
#
#                      GPX File
# count                     504
# unique                    504
# top     2018-11-11-140512.gpx
# freq                        1

# %% [markdown]
# # Selection in pandas
# - column selection
#     - df_var['column_name']
#     - df_var.column_name
#     - df_var[['column_name1', 'column_name2']]
#
# - row selection
#     - df_var.loc['row_name']
#     - df_var.iloc[row_index]
#     - df_var.iloc[row_index, column_index]

# %%
df['Date']
# Out:
# 0      2018-11-11 14:05:12
# 1      2018-11-09 15:02:35
# 2      2018-11-04 16:05:00
# 3      2018-11-01 14:03:58
# 4      2018-10-27 17:01:36
#               ...
# 503    2012-08-28 07:06:57
# 504    2012-08-24 12:59:42
# 505    2012-08-24 10:12:16
# 506    2012-08-24 08:13:12
# 507    2012-08-22 18:53:54
# Name: Date, Length: 508, dtype: object

# %%
df.Duration
# Out:
# 0        58:40
# 1      1:14:12
# 2      1:15:16
# 3      1:14:25
# 4      1:12:50
#         ...
# 503      13:39
# 504      17:56
# 505      13:43
# 506      16:00
# 507      31:08
# Name: Duration, Length: 508, dtype: object

# %%
df[['Date', 'Duration']] # dataframe
# Out:
#                     Date Duration
# 0    2018-11-11 14:05:12    58:40
# 1    2018-11-09 15:02:35  1:14:12
# 2    2018-11-04 16:05:00  1:15:16
# 3    2018-11-01 14:03:58  1:14:25
# 4    2018-10-27 17:01:36  1:12:50
# ..                   ...      ...
# 503  2012-08-28 07:06:57    13:39
# 504  2012-08-24 12:59:42    17:56
# 505  2012-08-24 10:12:16    13:43
# 506  2012-08-24 08:13:12    16:00
# 507  2012-08-22 18:53:54    31:08
#
# [508 rows x 2 columns]

# %%
cols = ['Date', 'Type', 'Duration', 'Average Speed (km/h)'] # Dataframe
df[cols]
# Out:
#                     Date     Type Duration  Average Speed (km/h)
# 0    2018-11-11 14:05:12  Running    58:40                 10.68
# 1    2018-11-09 15:02:35  Running  1:14:12                 10.39
# 2    2018-11-04 16:05:00  Running  1:15:16                 10.37
# 3    2018-11-01 14:03:58  Running  1:14:25                 10.47
# 4    2018-10-27 17:01:36  Running  1:12:50                 10.73
# ..                   ...      ...      ...                   ...
# 503  2012-08-28 07:06:57  Walking    13:39                  6.91
# 504  2012-08-24 12:59:42  Walking    17:56                  4.94
# 505  2012-08-24 10:12:16  Walking    13:43                  6.49
# 506  2012-08-24 08:13:12  Running    16:00                 11.82
# 507  2012-08-22 18:53:54  Running    31:08                 10.95
#
# [508 rows x 4 columns]

# %% [markdown]
# for people who are case-insensitive, you can use df_var.columns.str.lower() to convert all column names to lowercase

# %%
# listing all columns
df.columns.tolist()
# Out:
# ['Date',
#  'Activity Id',
#  'Type',
#  'Route Name',
#  'Distance (km)',
#  'Duration',
#  'Average Pace',
#  'Average Speed (km/h)',
#  'Calories Burned',
#  'Climb (m)',
#  'Average Heart Rate (bpm)',
#  "Friend's Tagged",
#  'Notes',
#  'GPX File']

# %%
df[['Date', 'Distance (km)']].head(25).plot(x='Date', y='Distance (km)',
                                      kind='bar', figsize=(15,5))
# Out:
# <Axes: xlabel='Date'>

# %%
df[['Date','Distance (km)', 'Average Heart Rate (bpm)']].head(25).plot(x='Date', y= ['Distance (km)','Average Heart Rate (bpm)'],
                                               kind='bar', figsize=(15,5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # row selection

# %%
df.loc[4] # 4 is taken as label
# Out:
# Date                                         2018-10-27 17:01:36
# Activity Id                 972567b2-1b0e-437c-9e82-fef8078d6438
# Type                                                     Running
# Route Name                                                   NaN
# Distance (km)                                              13.02
# Duration                                                 1:12:50
# Average Pace                                                5:36
# Average Speed (km/h)                                       10.73
# Calories Burned                                            967.0
# Climb (m)                                                    170
# Average Heart Rate (bpm)                                   154.0
# Friend's Tagged                                              NaN
# Notes                                                        NaN
# GPX File                                   2018-10-27-170136.gpx
# Name: 4, dtype: object

# %%
df.iloc[100] # 100 is taken as index
# Out:
# Date                                         2017-08-10 18:28:54
# Activity Id                 7b11bced-0b12-4e02-9717-09587f4c715f
# Type                                                     Running
# Route Name                                                   NaN
# Distance (km)                                               8.43
# Duration                                                   43:48
# Average Pace                                                5:12
# Average Speed (km/h)                                       11.54
# Calories Burned                                            596.0
# Climb (m)                                                     86
# Average Heart Rate (bpm)                                   147.0
# Friend's Tagged                                              NaN
# Notes                                      TomTom MySports Watch
# GPX File                                   2017-08-10-182854.gpx
# Name: 100, dtype: object

# %%
df.iloc[5:15] # 5: 15 -> 10 rows
# Out:
#                    Date                           Activity Id     Type  \
# 5   2018-10-19 17:52:32  fe2cb3fc-6330-40fa-8a92-0f86f4e72282  Running
# 6   2018-10-14 17:28:56  96acedc9-d3d5-4aac-8df4-f549a6418c1d  Running
# 7   2018-10-12 17:41:58  3c91092b-e6f3-4565-b540-6b6537358006  Running
# 8   2018-10-06 16:45:02  4c163abe-3a57-42fd-b50b-7f365960cbd4  Cycling
# 9   2018-09-30 16:52:34  70c7f2ba-f4cb-4403-a9e4-bf2c9b93bb05  Running
# 10  2018-09-16 14:55:03  30aaa821-1d3a-4f2f-9688-8543cebbd6e8  Cycling
# 11  2018-09-02 17:24:28  51781e97-560e-48d0-9522-44f303f9235f    Other
# 12  2018-09-01 17:06:15  2bd1841f-b428-4683-a41b-2bfb4be7e908  Cycling
# 13  2018-08-28 18:44:33  c9a8e088-441d-4b3f-bfbc-287e87585ca7  Cycling
# 14  2018-08-25 17:18:32  12723b6e-571b-4b68-be17-2c797982d3f9  Cycling
#
#    Route Name  Distance (km) Duration Average Pace  Average Speed (km/h)  \
# 5         NaN          10.29    59:18         5:46                 10.41
# 6         NaN          12.93  1:10:16         5:26                 11.04
# 7         NaN          12.31  1:09:26         5:38                 10.64
# 8         NaN          19.63  1:26:26         4:24                 13.63
# 9         NaN          12.97  1:13:56         5:42                 10.52
# 10        NaN          32.61  1:55:15         3:32                 16.98
# 11        NaN          17.65  1:01:28         3:29                 17.23
# 12        NaN          36.89  1:58:39         3:13                 18.65
# 13        NaN          28.17  1:27:07         3:06                 19.40
# 14        NaN          19.41  1:11:33         3:41                 16.28
#
#     Calories Burned  Climb (m)  Average Heart Rate (bpm)  Friend's Tagged  \
# 5             764.0        133                     155.0              NaN
# 6             953.0        159                     158.0              NaN
# 7             903.0        134                     157.0              NaN
# 8             577.0        210                      79.0              NaN
# 9             964.0        171                     156.0              NaN
# 10            830.0        462                     118.0              NaN
# 11           1164.0        219                      77.0              NaN
# 12            937.0        491                     122.0              NaN
# 13            685.0        400                     111.0              NaN
# 14            536.0        199                     124.0              NaN
#
#    Notes               GPX File
# 5    NaN  2018-10-19-175232.gpx
# 6    NaN  2018-10-14-172856.gpx
# 7    NaN  2018-10-12-174158.gpx
# 8    NaN  2018-10-06-164502.gpx
# 9    NaN  2018-09-30-165234.gpx
# 10   NaN  2018-09-16-145503.gpx
# 11   NaN  2018-09-02-172428.gpx
# 12   NaN  2018-09-01-170615.gpx
# 13   NaN  2018-08-28-184433.gpx
# 14   NaN  2018-08-25-171832.gpx

# %%
df.iloc[5:15, 2: 6] # 5:15 -> 10 rows and 2 to 5 columns
# Out:
#        Type Route Name  Distance (km) Duration
# 5   Running        NaN          10.29    59:18
# 6   Running        NaN          12.93  1:10:16
# 7   Running        NaN          12.31  1:09:26
# 8   Cycling        NaN          19.63  1:26:26
# 9   Running        NaN          12.97  1:13:56
# 10  Cycling        NaN          32.61  1:55:15
# 11    Other        NaN          17.65  1:01:28
# 12  Cycling        NaN          36.89  1:58:39
# 13  Cycling        NaN          28.17  1:27:07
# 14  Cycling        NaN          19.41  1:11:33

# %% [markdown]
# # basic mathemtical operations
#
# df_var['column_name'].operation()
#
# - sum()
# - mean()
# - median()
# - mode()
# - std()
# - var()

# %%
print(df['Distance (km)'].sum())
print(df['Distance (km)'].mean())
print(df['Distance (km)'].max(), '@',df['Distance (km)'].argmax()) # argmax() returns index
print(df['Climb (m)'].std())
print(df['Climb (m)'].median())
# Out:
# 5972.98
# 11.757834645669291
# 49.18 @ 87
# 108.52604010407185
# 92.0

# %% [markdown]
# # statistical operations on dataframe
# - df_var.corr() : correlation between columns (numerical columns only)
# - df_var.count() : count of non-null values in each column
# - df_var.max() : maximum value in each column (numerical columns only)
# - df_var.min() : minimum value in each column (numerical columns only)

# %%
df[['Calories Burned', 'Climb (m)', 'Average Heart Rate (bpm)']].corr()
# Out:
#                           Calories Burned  Climb (m)  Average Heart Rate (bpm)
# Calories Burned                  1.000000  -0.079937                  0.084554
# Climb (m)                       -0.079937   1.000000                 -0.081439
# Average Heart Rate (bpm)         0.084554  -0.081439                  1.000000

# %%
sns.relplot(x='Calories Burned', y='Average Heart Rate (bpm)', data=df, aspect=2)

# %%
df.count() # count the number of non-null values in each column
# Out:
# Date                        508
# Activity Id                 508
# Type                        508
# Route Name                    1
# Distance (km)               508
# Duration                    508
# Average Pace                508
# Average Speed (km/h)        508
# Calories Burned             508
# Climb (m)                   508
# Average Heart Rate (bpm)    294
# Friend's Tagged               0
# Notes                       231
# GPX File                    504
# dtype: int64

# %%
df.select_dtypes(include='number').max() # select all numeric columns then find max
# Out:
# Distance (km)                    49.18
# Average Speed (km/h)             24.33
# Calories Burned             4072685.00
# Climb (m)                       982.00
# Average Heart Rate (bpm)        172.00
# Friend's Tagged                    NaN
# dtype: float64

# %% [markdown]
# # dataframe manipulation
#
# - sorting
#     - df_var.sort_values(by='column_name')
#     - df_var.sort_values(by='column_name', ascending=False)
#
# - adding new columns
#     - df_var['new_column_name'] = df_var['column_name1'] + df_var['column_name2']
# - dropping columns
#     - df_var.drop('column_name', axis=1)

# %%
df.sort_values(by='Distance (km)').tail(25).plot(x='Date', y=['Distance (km)','Average Speed (km/h)','Average Heart Rate (bpm)'],
                                            kind='bar', figsize=(15,5))
# Out:
# <Axes: xlabel='Date'>
